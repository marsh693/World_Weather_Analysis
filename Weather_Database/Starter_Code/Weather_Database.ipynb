# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size =2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size =2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 750

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | palomares
# Processing Record 2 of Set 1 | saint-augustin
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | bambous virieux
# Processing Record 5 of Set 1 | cabo san lucas
# Processing Record 6 of Set 1 | khorinsk
# Processing Record 7 of Set 1 | berlevag
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | aksaray
# Processing Record 11 of Set 1 | portel
# Processing Record 12 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | herat
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | oranjestad
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | sobolevo
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | almeirim
# Processing Record 29 of Set 1 | lufilufi
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | sham churasi
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | kattivakkam
# Processing Record 35 of Set 1 | ucluelet
# Processing Record 36 of Set 1 | datong
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | portland
# Processing Record 39 of Set 1 | deputatskiy
# Processing Record 40 of Set 1 | gurskoye
# City not found. Skipping...
# Processing Record 41 of Set 1 | sulurpeta
# City not found. Skipping...
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | itarema
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | severo-yeniseyskiy
# Processing Record 48 of Set 1 | porto novo
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | brufut
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | pemangkat
# Processing Record 4 of Set 2 | xuchang
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | vardo
# Processing Record 8 of Set 2 | san cristobal
# Processing Record 9 of Set 2 | olafsvik
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | coracora
# Processing Record 16 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 2 | tamandare
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | norwich
# Processing Record 22 of Set 2 | nemuro
# Processing Record 23 of Set 2 | gizo
# Processing Record 24 of Set 2 | benguela
# Processing Record 25 of Set 2 | ganzhou
# Processing Record 26 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 2 | neuquen
# Processing Record 28 of Set 2 | dunedin
# Processing Record 29 of Set 2 | aklavik
# Processing Record 30 of Set 2 | zalantun
# Processing Record 31 of Set 2 | bathsheba
# Processing Record 32 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 2 | fort nelson
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | arman
# Processing Record 37 of Set 2 | salalah
# Processing Record 38 of Set 2 | rio rancho
# Processing Record 39 of Set 2 | faya
# Processing Record 40 of Set 2 | rocha
# Processing Record 41 of Set 2 | huron
# Processing Record 42 of Set 2 | punta alta
# Processing Record 43 of Set 2 | moose factory
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 2 | namibe
# Processing Record 47 of Set 2 | botucatu
# Processing Record 48 of Set 2 | marathon
# Processing Record 49 of Set 2 | joshimath
# Processing Record 50 of Set 2 | belmonte
# Processing Record 1 of Set 3 | kaitangata
# Processing Record 2 of Set 3 | dikson
# Processing Record 3 of Set 3 | simao dias
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | provideniya
# Processing Record 7 of Set 3 | lima
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | pimentel
# Processing Record 10 of Set 3 | mukhen
# Processing Record 11 of Set 3 | maneadero
# Processing Record 12 of Set 3 | ullapool
# Processing Record 13 of Set 3 | port lincoln
# Processing Record 14 of Set 3 | kruisfontein
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 3 | constitucion
# Processing Record 18 of Set 3 | barrow
# Processing Record 19 of Set 3 | fortuna
# Processing Record 20 of Set 3 | atambua
# Processing Record 21 of Set 3 | ugoofaaru
# Processing Record 22 of Set 3 | lavrentiya
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | nastola
# Processing Record 26 of Set 3 | havelock
# Processing Record 27 of Set 3 | vila do maio
# Processing Record 28 of Set 3 | vao
# Processing Record 29 of Set 3 | byron bay
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | phonhong
# Processing Record 32 of Set 3 | vestmanna
# Processing Record 33 of Set 3 | hambantota
# Processing Record 34 of Set 3 | hermanus
# Processing Record 35 of Set 3 | vaini
# Processing Record 36 of Set 3 | mangrol
# Processing Record 37 of Set 3 | dong hoi
# Processing Record 38 of Set 3 | fengrun
# Processing Record 39 of Set 3 | pasni
# Processing Record 40 of Set 3 | port elizabeth
# Processing Record 41 of Set 3 | komsomolskiy
# Processing Record 42 of Set 3 | bengkulu
# Processing Record 43 of Set 3 | coihaique
# Processing Record 44 of Set 3 | catarman
# Processing Record 45 of Set 3 | kirillov
# Processing Record 46 of Set 3 | beringovskiy
# Processing Record 47 of Set 3 | yenagoa
# Processing Record 48 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 50 of Set 3 | assiniboia
# Processing Record 1 of Set 4 | muravlenko
# Processing Record 2 of Set 4 | mahebourg
# Processing Record 3 of Set 4 | ketchikan
# Processing Record 4 of Set 4 | jalu
# Processing Record 5 of Set 4 | taicheng
# Processing Record 6 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 7 of Set 4 | kavieng
# Processing Record 8 of Set 4 | airai
# Processing Record 9 of Set 4 | hofn
# Processing Record 10 of Set 4 | port-gentil
# Processing Record 11 of Set 4 | bonavista
# Processing Record 12 of Set 4 | batemans bay
# Processing Record 13 of Set 4 | dryden
# Processing Record 14 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 4 | blagoyevo
# Processing Record 16 of Set 4 | cherskiy
# Processing Record 17 of Set 4 | wanaka
# Processing Record 18 of Set 4 | hastings
# Processing Record 19 of Set 4 | tlahualilo
# City not found. Skipping...
# Processing Record 20 of Set 4 | garissa
# Processing Record 21 of Set 4 | lensk
# Processing Record 22 of Set 4 | san rafael del sur
# Processing Record 23 of Set 4 | sena madureira
# Processing Record 24 of Set 4 | faanui
# Processing Record 25 of Set 4 | mehamn
# Processing Record 26 of Set 4 | torbay
# Processing Record 27 of Set 4 | maraa
# Processing Record 28 of Set 4 | shieli
# Processing Record 29 of Set 4 | westport
# Processing Record 30 of Set 4 | vestmannaeyjar
# Processing Record 31 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 32 of Set 4 | alice springs
# Processing Record 33 of Set 4 | haines junction
# Processing Record 34 of Set 4 | padang
# Processing Record 35 of Set 4 | ryotsu
# Processing Record 36 of Set 4 | touros
# Processing Record 37 of Set 4 | ahuimanu
# Processing Record 38 of Set 4 | namatanai
# Processing Record 39 of Set 4 | narsaq
# Processing Record 40 of Set 4 | san quintin
# Processing Record 41 of Set 4 | yerbogachen
# Processing Record 42 of Set 4 | koubia
# Processing Record 43 of Set 4 | hualmay
# Processing Record 44 of Set 4 | barreirinha
# Processing Record 45 of Set 4 | husavik
# Processing Record 46 of Set 4 | longyearbyen
# Processing Record 47 of Set 4 | telemaco borba
# Processing Record 48 of Set 4 | champerico
# Processing Record 49 of Set 4 | kaniama
# Processing Record 50 of Set 4 | naron
# Processing Record 1 of Set 5 | albion
# Processing Record 2 of Set 5 | bintulu
# Processing Record 3 of Set 5 | ust-kuyga
# Processing Record 4 of Set 5 | atar
# Processing Record 5 of Set 5 | upernavik
# Processing Record 6 of Set 5 | saint anthony
# Processing Record 7 of Set 5 | ambulu
# Processing Record 8 of Set 5 | kuleshovka
# Processing Record 9 of Set 5 | imeni zhelyabova
# Processing Record 10 of Set 5 | coquimbo
# Processing Record 11 of Set 5 | reforma
# Processing Record 12 of Set 5 | leningradskiy
# Processing Record 13 of Set 5 | maragogi
# Processing Record 14 of Set 5 | north bend
# Processing Record 15 of Set 5 | megion
# Processing Record 16 of Set 5 | raipur
# Processing Record 17 of Set 5 | baiyin
# Processing Record 18 of Set 5 | pangnirtung
# Processing Record 19 of Set 5 | przhevalskoye
# Processing Record 20 of Set 5 | laguna
# Processing Record 21 of Set 5 | skibbereen
# Processing Record 22 of Set 5 | norman wells
# Processing Record 23 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 5 | san patricio
# Processing Record 26 of Set 5 | kangaatsiaq
# Processing Record 27 of Set 5 | beyneu
# Processing Record 28 of Set 5 | boende
# Processing Record 29 of Set 5 | nefteyugansk
# Processing Record 30 of Set 5 | yambio
# Processing Record 31 of Set 5 | mount gambier
# Processing Record 32 of Set 5 | nalut
# Processing Record 33 of Set 5 | severo-kurilsk
# Processing Record 34 of Set 5 | tectitan
# City not found. Skipping...
# Processing Record 35 of Set 5 | charters towers
# Processing Record 36 of Set 5 | grindavik
# Processing Record 37 of Set 5 | san ignacio
# Processing Record 38 of Set 5 | nouadhibou
# Processing Record 39 of Set 5 | soderhamn
# Processing Record 40 of Set 5 | burnie
# Processing Record 41 of Set 5 | anadyr
# Processing Record 42 of Set 5 | amuntai
# Processing Record 43 of Set 5 | wschowa
# Processing Record 44 of Set 5 | dalvik
# Processing Record 45 of Set 5 | lagoa
# Processing Record 46 of Set 5 | tasiilaq
# Processing Record 47 of Set 5 | yumen
# Processing Record 48 of Set 5 | remontnoye
# Processing Record 49 of Set 5 | weligama
# Processing Record 50 of Set 5 | trelew
# Processing Record 1 of Set 6 | carnarvon
# Processing Record 2 of Set 6 | powell
# Processing Record 3 of Set 6 | dourados
# Processing Record 4 of Set 6 | callaguip
# Processing Record 5 of Set 6 | sitka
# Processing Record 6 of Set 6 | massakory
# Processing Record 7 of Set 6 | santa rosa
# Processing Record 8 of Set 6 | dalbandin
# Processing Record 9 of Set 6 | tilichiki
# Processing Record 10 of Set 6 | kahului
# Processing Record 11 of Set 6 | bandarbeyla
# Processing Record 12 of Set 6 | tiznit
# Processing Record 13 of Set 6 | geraldton
# Processing Record 14 of Set 6 | villa guerrero
# Processing Record 15 of Set 6 | vallenar
# Processing Record 16 of Set 6 | cidreira
# Processing Record 17 of Set 6 | khuzdar
# Processing Record 18 of Set 6 | zhigansk
# Processing Record 19 of Set 6 | saldanha
# Processing Record 20 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 22 of Set 6 | praia
# Processing Record 23 of Set 6 | lata
# Processing Record 24 of Set 6 | praia da vitoria
# Processing Record 25 of Set 6 | awbari
# Processing Record 26 of Set 6 | sitangkai
# Processing Record 27 of Set 6 | santiago del estero
# Processing Record 28 of Set 6 | oranjemund
# Processing Record 29 of Set 6 | los llanos de aridane
# Processing Record 30 of Set 6 | llorente
# Processing Record 31 of Set 6 | sao gabriel da cachoeira
# Processing Record 32 of Set 6 | roma
# Processing Record 33 of Set 6 | dingle
# Processing Record 34 of Set 6 | moron
# Processing Record 35 of Set 6 | ponta do sol
# Processing Record 36 of Set 6 | sinnamary
# Processing Record 37 of Set 6 | maebaru
# Processing Record 38 of Set 6 | pevek
# Processing Record 39 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 6 | phatthalung
# Processing Record 41 of Set 6 | marsa matruh
# Processing Record 42 of Set 6 | oliver
# Processing Record 43 of Set 6 | dongsheng
# Processing Record 44 of Set 6 | cessnock
# Processing Record 45 of Set 6 | jiuquan
# Processing Record 46 of Set 6 | dzhebariki-khaya
# Processing Record 47 of Set 6 | malakal
# Processing Record 48 of Set 6 | neustadt
# Processing Record 49 of Set 6 | kurtalan
# Processing Record 50 of Set 6 | inhambane
# Processing Record 1 of Set 7 | jiazi
# Processing Record 2 of Set 7 | saint-louis
# Processing Record 3 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 7 | mocuba
# Processing Record 6 of Set 7 | picos
# Processing Record 7 of Set 7 | qaqortoq
# Processing Record 8 of Set 7 | impfondo
# Processing Record 9 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 7 | tura
# Processing Record 12 of Set 7 | palmer
# Processing Record 13 of Set 7 | lytkarino
# Processing Record 14 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 15 of Set 7 | kabompo
# Processing Record 16 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 7 | bay roberts
# Processing Record 18 of Set 7 | marsh harbour
# Processing Record 19 of Set 7 | mandello del lario
# Processing Record 20 of Set 7 | ossora
# Processing Record 21 of Set 7 | lompoc
# Processing Record 22 of Set 7 | kismayo
# Processing Record 23 of Set 7 | paka
# Processing Record 24 of Set 7 | gafanha da encarnacao
# Processing Record 25 of Set 7 | sao filipe
# Processing Record 26 of Set 7 | hasaki
# Processing Record 27 of Set 7 | trinidad
# Processing Record 28 of Set 7 | sergeyevka
# Processing Record 29 of Set 7 | klaksvik
# Processing Record 30 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 31 of Set 7 | bridlington
# Processing Record 32 of Set 7 | glenwood springs
# Processing Record 33 of Set 7 | qurayyat
# Processing Record 34 of Set 7 | sorland
# Processing Record 35 of Set 7 | rosamorada
# Processing Record 36 of Set 7 | shenjiamen
# Processing Record 37 of Set 7 | vila velha
# Processing Record 38 of Set 7 | birin
# Processing Record 39 of Set 7 | beisfjord
# Processing Record 40 of Set 7 | morro bay
# Processing Record 41 of Set 7 | samarai
# Processing Record 42 of Set 7 | wenling
# Processing Record 43 of Set 7 | agde
# Processing Record 44 of Set 7 | boden
# Processing Record 45 of Set 7 | lakes entrance
# Processing Record 46 of Set 7 | safford
# Processing Record 47 of Set 7 | the valley
# Processing Record 48 of Set 7 | inzer
# Processing Record 49 of Set 7 | hamilton
# Processing Record 50 of Set 7 | college
# Processing Record 1 of Set 8 | wawa
# Processing Record 2 of Set 8 | yulara
# Processing Record 3 of Set 8 | tunceli
# Processing Record 4 of Set 8 | diamantino
# Processing Record 5 of Set 8 | zeya
# Processing Record 6 of Set 8 | aloleng
# Processing Record 7 of Set 8 | nelson bay
# Processing Record 8 of Set 8 | kalmunai
# Processing Record 9 of Set 8 | havoysund
# Processing Record 10 of Set 8 | teknaf
# Processing Record 11 of Set 8 | souillac
# Processing Record 12 of Set 8 | leh
# Processing Record 13 of Set 8 | kavaratti
# Processing Record 14 of Set 8 | imphal
# Processing Record 15 of Set 8 | luderitz
# Processing Record 16 of Set 8 | bahia honda
# Processing Record 17 of Set 8 | tezu
# Processing Record 18 of Set 8 | clyde river
# Processing Record 19 of Set 8 | hirara
# Processing Record 20 of Set 8 | noyabrsk
# Processing Record 21 of Set 8 | dahuk
# Processing Record 22 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 8 | mandiana
# Processing Record 24 of Set 8 | manjacaze
# Processing Record 25 of Set 8 | san luis
# Processing Record 26 of Set 8 | prince rupert
# Processing Record 27 of Set 8 | warin chamrap
# Processing Record 28 of Set 8 | shingu
# Processing Record 29 of Set 8 | zurrieq
# Processing Record 30 of Set 8 | kudahuvadhoo
# Processing Record 31 of Set 8 | guadalupe victoria
# Processing Record 32 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 8 | timmins
# Processing Record 34 of Set 8 | waingapu
# Processing Record 35 of Set 8 | valentin gomez farias
# Processing Record 36 of Set 8 | katsuura
# Processing Record 37 of Set 8 | chokurdakh
# Processing Record 38 of Set 8 | lasa
# Processing Record 39 of Set 8 | vaitape
# Processing Record 40 of Set 8 | yunhe
# Processing Record 41 of Set 8 | krasnogorodsk
# Processing Record 42 of Set 8 | chara
# Processing Record 43 of Set 8 | feijo
# Processing Record 44 of Set 8 | bolshaya martynovka
# Processing Record 45 of Set 8 | prieska
# Processing Record 46 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 8 | ayaviri
# Processing Record 48 of Set 8 | lorengau
# Processing Record 49 of Set 8 | dhoraji
# Processing Record 50 of Set 8 | karratha
# Processing Record 1 of Set 9 | progreso
# Processing Record 2 of Set 9 | santa rosalia
# Processing Record 3 of Set 9 | lebu
# Processing Record 4 of Set 9 | jumla
# Processing Record 5 of Set 9 | sakakah
# Processing Record 6 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 7 of Set 9 | djibo
# Processing Record 8 of Set 9 | brigantine
# Processing Record 9 of Set 9 | kottagudem
# Processing Record 10 of Set 9 | warman
# Processing Record 11 of Set 9 | kemijarvi
# Processing Record 12 of Set 9 | zatoka
# Processing Record 13 of Set 9 | josanicka banja
# Processing Record 14 of Set 9 | banovce
# City not found. Skipping...
# Processing Record 15 of Set 9 | ekhabi
# Processing Record 16 of Set 9 | guane
# Processing Record 17 of Set 9 | bereda
# Processing Record 18 of Set 9 | piacabucu
# Processing Record 19 of Set 9 | micheweni
# Processing Record 20 of Set 9 | kuala terengganu
# Processing Record 21 of Set 9 | ambilobe
# Processing Record 22 of Set 9 | fairbanks
# Processing Record 23 of Set 9 | laramie
# Processing Record 24 of Set 9 | kununurra
# Processing Record 25 of Set 9 | sur
# Processing Record 26 of Set 9 | waldkirchen
# Processing Record 27 of Set 9 | salta
# Processing Record 28 of Set 9 | gornopravdinsk
# Processing Record 29 of Set 9 | yar-sale
# Processing Record 30 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 9 | oussouye
# Processing Record 32 of Set 9 | almaty
# Processing Record 33 of Set 9 | yeppoon
# Processing Record 34 of Set 9 | polyarnyy
# Processing Record 35 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 9 | isla mujeres
# Processing Record 37 of Set 9 | belle fourche
# Processing Record 38 of Set 9 | bela
# Processing Record 39 of Set 9 | waw
# Processing Record 40 of Set 9 | apple valley
# Processing Record 41 of Set 9 | iquitos
# Processing Record 42 of Set 9 | skjervoy
# Processing Record 43 of Set 9 | mackenzie
# Processing Record 44 of Set 9 | slave lake
# Processing Record 45 of Set 9 | san roque
# Processing Record 46 of Set 9 | tuatapere
# Processing Record 47 of Set 9 | sri aman
# Processing Record 48 of Set 9 | straumen
# Processing Record 49 of Set 9 | nome
# Processing Record 50 of Set 9 | fengzhen
# Processing Record 1 of Set 10 | ostrovnoy
# Processing Record 2 of Set 10 | pueblo
# Processing Record 3 of Set 10 | mandalgovi
# Processing Record 4 of Set 10 | alvaraes
# Processing Record 5 of Set 10 | praya
# Processing Record 6 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 7 of Set 10 | clemson
# Processing Record 8 of Set 10 | dolgoye
# Processing Record 9 of Set 10 | balgazyn
# Processing Record 10 of Set 10 | ilulissat
# Processing Record 11 of Set 10 | kisumu
# Processing Record 12 of Set 10 | khandyga
# Processing Record 13 of Set 10 | rockport
# Processing Record 14 of Set 10 | gobabis
# Processing Record 15 of Set 10 | slupca
# Processing Record 16 of Set 10 | imbituba
# Processing Record 17 of Set 10 | nguruka
# Processing Record 18 of Set 10 | galway
# Processing Record 19 of Set 10 | palu
# Processing Record 20 of Set 10 | boyuibe
# Processing Record 21 of Set 10 | korla
# Processing Record 22 of Set 10 | emerald
# Processing Record 23 of Set 10 | margate
# Processing Record 24 of Set 10 | dubovskoye
# Processing Record 25 of Set 10 | dwarka
# Processing Record 26 of Set 10 | sibolga
# Processing Record 27 of Set 10 | aksarka
# Processing Record 28 of Set 10 | kasongo
# Processing Record 29 of Set 10 | niltepec
# Processing Record 30 of Set 10 | richland
# Processing Record 31 of Set 10 | kirakira
# Processing Record 32 of Set 10 | chute-aux-outardes
# Processing Record 33 of Set 10 | sistranda
# Processing Record 34 of Set 10 | port macquarie
# Processing Record 35 of Set 10 | turka
# Processing Record 36 of Set 10 | boralday
# Processing Record 37 of Set 10 | biltine
# Processing Record 38 of Set 10 | buba
# Processing Record 39 of Set 10 | morehead
# Processing Record 40 of Set 10 | ginda
# Processing Record 41 of Set 10 | burica
# City not found. Skipping...
# Processing Record 42 of Set 10 | okhotsk
# Processing Record 43 of Set 10 | berdigestyakh
# Processing Record 44 of Set 10 | kevsala
# Processing Record 45 of Set 10 | cuamba
# Processing Record 46 of Set 10 | paamiut
# Processing Record 47 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 10 | salinopolis
# Processing Record 49 of Set 10 | mitsamiouli
# Processing Record 50 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 11 | toora-khem
# Processing Record 2 of Set 11 | atessa
# Processing Record 3 of Set 11 | huamuxtitlan
# Processing Record 4 of Set 11 | zhicheng
# Processing Record 5 of Set 11 | yusva
# City not found. Skipping...
# Processing Record 6 of Set 11 | kahone
# Processing Record 7 of Set 11 | chardara
# Processing Record 8 of Set 11 | ust-nera
# Processing Record 9 of Set 11 | magistralnyy
# Processing Record 10 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 11 | kupang
# Processing Record 12 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 13 of Set 11 | vozrozhdeniye
# Processing Record 14 of Set 11 | bilibino
# Processing Record 15 of Set 11 | hevizgyork
# City not found. Skipping...
# Processing Record 16 of Set 11 | amazar
# Processing Record 17 of Set 11 | hobyo
# Processing Record 18 of Set 11 | voi
# Processing Record 19 of Set 11 | novobirilyussy
# Processing Record 20 of Set 11 | zemio
# Processing Record 21 of Set 11 | cumberland
# Processing Record 22 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 11 | ust-koksa
# Processing Record 25 of Set 11 | talnakh
# Processing Record 26 of Set 11 | strelka
# Processing Record 27 of Set 11 | opuwo
# Processing Record 28 of Set 11 | junagarh
# Processing Record 29 of Set 11 | usogorsk
# Processing Record 30 of Set 11 | bogorodskoye
# Processing Record 31 of Set 11 | golden
# Processing Record 32 of Set 11 | nampula
# Processing Record 33 of Set 11 | ternate
# Processing Record 34 of Set 11 | tomatlan
# Processing Record 35 of Set 11 | sao bernardo
# Processing Record 36 of Set 11 | kudymkar
# Processing Record 37 of Set 11 | bonthe
# Processing Record 38 of Set 11 | uvat
# Processing Record 39 of Set 11 | baghdad
# Processing Record 40 of Set 11 | osoyoos
# Processing Record 41 of Set 11 | bojnurd
# Processing Record 42 of Set 11 | knysna
# Processing Record 43 of Set 11 | aswan
# Processing Record 44 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 45 of Set 11 | saint-pierre
# Processing Record 46 of Set 11 | raga
# Processing Record 47 of Set 11 | kalabo
# Processing Record 48 of Set 11 | oktyabrskiy
# Processing Record 49 of Set 11 | galesong
# Processing Record 50 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 12 | itaqui
# Processing Record 2 of Set 12 | panubigan
# Processing Record 3 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 12 | omboue
# Processing Record 5 of Set 12 | erdenet
# Processing Record 6 of Set 12 | asau
# Processing Record 7 of Set 12 | shahr-e kord
# Processing Record 8 of Set 12 | horodyshche
# Processing Record 9 of Set 12 | mananjary
# Processing Record 10 of Set 12 | san jose
# Processing Record 11 of Set 12 | batagay-alyta
# Processing Record 12 of Set 12 | kysyl-syr
# Processing Record 13 of Set 12 | sioux lookout
# Processing Record 14 of Set 12 | atikokan
# Processing Record 15 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 16 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 12 | verkhnyaya inta
# Processing Record 18 of Set 12 | elko
# Processing Record 19 of Set 12 | bolshiye uki
# City not found. Skipping...
# Processing Record 20 of Set 12 | mizan teferi
# Processing Record 21 of Set 12 | trairi
# Processing Record 22 of Set 12 | ardakan
# Processing Record 23 of Set 12 | mangai
# Processing Record 24 of Set 12 | parana
# Processing Record 25 of Set 12 | morrope
# Processing Record 26 of Set 12 | siilinjarvi
# Processing Record 27 of Set 12 | durant
# Processing Record 28 of Set 12 | biak
# Processing Record 29 of Set 12 | bontang
# Processing Record 30 of Set 12 | ahipara
# Processing Record 31 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 32 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 33 of Set 12 | rio gallegos
# Processing Record 34 of Set 12 | san juan
# Processing Record 35 of Set 12 | ust-omchug
# Processing Record 36 of Set 12 | hervey bay
# Processing Record 37 of Set 12 | sangar
# Processing Record 38 of Set 12 | yining
# Processing Record 39 of Set 12 | santa vitoria do palmar
# Processing Record 40 of Set 12 | lososina
# Processing Record 41 of Set 12 | saquena
# Processing Record 42 of Set 12 | kentau
# Processing Record 43 of Set 12 | ballina
# Processing Record 44 of Set 12 | augusto correa
# Processing Record 45 of Set 12 | longyan
# Processing Record 46 of Set 12 | jining
# Processing Record 47 of Set 12 | cartagena
# Processing Record 48 of Set 12 | najran
# Processing Record 49 of Set 12 | camacha
# Processing Record 50 of Set 12 | nanortalik
# Processing Record 1 of Set 13 | mataram
# Processing Record 2 of Set 13 | broken hill
# Processing Record 3 of Set 13 | port hardy
# Processing Record 4 of Set 13 | ulaangom
# Processing Record 5 of Set 13 | muros
# Processing Record 6 of Set 13 | pareora
# Processing Record 7 of Set 13 | pines
# Processing Record 8 of Set 13 | burgeo
# Processing Record 9 of Set 13 | kloulklubed
# Processing Record 10 of Set 13 | mondeville
# Processing Record 11 of Set 13 | cap-haitien
# Processing Record 12 of Set 13 | tema
# Processing Record 13 of Set 13 | plettenberg bay
# Processing Record 14 of Set 13 | porto belo
# Processing Record 15 of Set 13 | wukari
# Processing Record 16 of Set 13 | benjamin hill
# Processing Record 17 of Set 13 | honningsvag
# Processing Record 18 of Set 13 | llangefni
# Processing Record 19 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 21 of Set 13 | mayo
# Processing Record 22 of Set 13 | bubaque
# Processing Record 23 of Set 13 | teberda
# Processing Record 24 of Set 13 | douglas
# Processing Record 25 of Set 13 | te anau
# Processing Record 26 of Set 13 | avera
# Processing Record 27 of Set 13 | pachora
# Processing Record 28 of Set 13 | umm kaddadah
# Processing Record 29 of Set 13 | kampene
# Processing Record 30 of Set 13 | caravelas
# Processing Record 31 of Set 13 | viedma
# Processing Record 32 of Set 13 | seoul
# Processing Record 33 of Set 13 | cabedelo
# Processing Record 34 of Set 13 | adrar
# Processing Record 35 of Set 13 | antofagasta
# Processing Record 36 of Set 13 | abomsa
# Processing Record 37 of Set 13 | belyy yar
# Processing Record 38 of Set 13 | curico
# Processing Record 39 of Set 13 | puerto quijarro
# Processing Record 40 of Set 13 | ati
# Processing Record 41 of Set 13 | cukai
# Processing Record 42 of Set 13 | uyuni
# Processing Record 43 of Set 13 | kasama
# Processing Record 44 of Set 13 | howard springs
# Processing Record 45 of Set 13 | gold coast
# Processing Record 46 of Set 13 | saint george
# Processing Record 47 of Set 13 | dharchula
# Processing Record 48 of Set 13 | abha
# Processing Record 49 of Set 13 | garwa
# Processing Record 50 of Set 13 | ahome
# Processing Record 1 of Set 14 | masyaf
# Processing Record 2 of Set 14 | ayan
# Processing Record 3 of Set 14 | half moon bay
# Processing Record 4 of Set 14 | boa vista
# Processing Record 5 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 14 | walvis bay
# Processing Record 7 of Set 14 | idah
# Processing Record 8 of Set 14 | anchorage
# Processing Record 9 of Set 14 | orlik
# Processing Record 10 of Set 14 | patea
# Processing Record 11 of Set 14 | naze
# Processing Record 12 of Set 14 | granada
# Processing Record 13 of Set 14 | teeli
# Processing Record 14 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 15 of Set 14 | rorvik
# Processing Record 16 of Set 14 | lahij
# Processing Record 17 of Set 14 | balkhash
# Processing Record 18 of Set 14 | sept-iles
# Processing Record 19 of Set 14 | mandurah
# Processing Record 20 of Set 14 | cockburn town
# Processing Record 21 of Set 14 | manzanillo
# Processing Record 22 of Set 14 | zubtsov
# Processing Record 23 of Set 14 | waipawa
# Processing Record 24 of Set 14 | namanyere
# Processing Record 25 of Set 14 | huarmey
# Processing Record 26 of Set 14 | gamba
# Processing Record 27 of Set 14 | belaya gora
# Processing Record 28 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 29 of Set 14 | gorin
# Processing Record 30 of Set 14 | ondjiva
# Processing Record 31 of Set 14 | kurumkan
# Processing Record 32 of Set 14 | salaga
# Processing Record 33 of Set 14 | bari
# Processing Record 34 of Set 14 | lodja
# Processing Record 35 of Set 14 | gat
# Processing Record 36 of Set 14 | ankang
# Processing Record 37 of Set 14 | sao miguel do araguaia
# Processing Record 38 of Set 14 | sao tome
# Processing Record 39 of Set 14 | gap
# Processing Record 40 of Set 14 | freetown
# Processing Record 41 of Set 14 | guerrero negro
# Processing Record 42 of Set 14 | rabak
# Processing Record 43 of Set 14 | formosa
# Processing Record 44 of Set 14 | eydhafushi
# Processing Record 45 of Set 14 | sao jose da coroa grande
# Processing Record 46 of Set 14 | ancud
# Processing Record 47 of Set 14 | mweka
# Processing Record 48 of Set 14 | nanakuli
# Processing Record 49 of Set 14 | kaeo
# Processing Record 50 of Set 14 | vila
# Processing Record 1 of Set 15 | ilo
# Processing Record 2 of Set 15 | san vicente
# Processing Record 3 of Set 15 | newport
# Processing Record 4 of Set 15 | nishihara
# Processing Record 5 of Set 15 | choya
# Processing Record 6 of Set 15 | braganca
# Processing Record 7 of Set 15 | princeton
# Processing Record 8 of Set 15 | flinders
# Processing Record 9 of Set 15 | bireun
# Processing Record 10 of Set 15 | cody
# Processing Record 11 of Set 15 | tourlaville
# Processing Record 12 of Set 15 | batagay
# Processing Record 13 of Set 15 | urumqi
# Processing Record 14 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 15 | tikapur
# Processing Record 16 of Set 15 | puerto escondido
# Processing Record 17 of Set 15 | mapiripan
# Processing Record 18 of Set 15 | port augusta
# Processing Record 19 of Set 15 | issenye
# Processing Record 20 of Set 15 | lev tolstoy
# Processing Record 21 of Set 15 | port blair
# Processing Record 22 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 15 | bahia blanca
# Processing Record 25 of Set 15 | maryville
# Processing Record 26 of Set 15 | newark
# Processing Record 27 of Set 15 | arandis
# Processing Record 28 of Set 15 | mjolby
# Processing Record 29 of Set 15 | colares
# Processing Record 30 of Set 15 | oktyabrskoye
# Processing Record 31 of Set 15 | ulsteinvik
# Processing Record 32 of Set 15 | sorong
# Processing Record 33 of Set 15 | ilinskiy
# Processing Record 34 of Set 15 | molochnoye
# Processing Record 35 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 15 | birao
# Processing Record 37 of Set 15 | rio grande
# Processing Record 38 of Set 15 | holme
# Processing Record 39 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 15 | wabag
# Processing Record 41 of Set 15 | mahajanga
# Processing Record 42 of Set 15 | alofi
# Processing Record 43 of Set 15 | aden
# Processing Record 44 of Set 15 | marzuq
# Processing Record 45 of Set 15 | acarau
# Processing Record 46 of Set 15 | nong khai
# Processing Record 47 of Set 15 | svetlyy
# Processing Record 48 of Set 15 | brae
# Processing Record 49 of Set 15 | forecariah
# Processing Record 50 of Set 15 | evensk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 685

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Palomares  17.1500  -95.0667     81.50        63          15
# 1   Saint-Augustin  51.2260  -58.6502     22.33        97          99
# 2  Arraial Do Cabo -22.9661  -42.0278     78.66        69           0
# 3  Bambous Virieux -20.3428   57.7575     76.21        88          75
# 4   Cabo San Lucas  22.8909 -109.9124     76.60        60           0
# 5         Khorinsk  52.1657  109.7726    -24.23        99          58
# 6         Berlevag  70.8578   29.0864     28.40        69         100
# 7   Saint-Philippe -21.3585   55.7679     76.59        78          69
# 8    Mar Del Plata -38.0023  -57.5575     71.83        63           0
# 9          Aksaray  38.3726   34.0254     32.70        40           0
#
#    Wind Speed Country Current Description
# 0       13.96      MX          few clouds
# 1        4.43      CA     overcast clouds
# 2       20.71      BR           clear sky
# 3        4.61      MU       broken clouds
# 4       12.66      MX           clear sky
# 5        1.61      RU       broken clouds
# 6       13.80      NO     overcast clouds
# 7        6.42      RE       broken clouds
# 8       10.36      AR           clear sky
# 9        0.47      TR           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity',
                    'Cloudiness', 'Wind Speed', 'Current Description'] 

# Recreate the DataFrame by using the new column order
city_df = city_data_df[new_column_order]
city_df.head(10)

# Display sample data
city_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Palomares      MX  17.1500  -95.0667     81.50        63
# 1     Saint-Augustin      CA  51.2260  -58.6502     22.33        97
# 2    Arraial Do Cabo      BR -22.9661  -42.0278     78.66        69
# 3    Bambous Virieux      MU -20.3428   57.7575     76.21        88
# 4     Cabo San Lucas      MX  22.8909 -109.9124     76.60        60
# ..               ...     ...      ...       ...       ...       ...
# 680        Nong Khai      TH  17.9167  103.0833     69.17        65
# 681          Svetlyy      RU  54.6750   20.1347     46.45        82
# 682             Brae      GB  60.3964   -1.3530     37.78        87
# 683       Forecariah      GN   9.4306  -13.0881     72.18        78
# 684           Evensk      RU  61.9500  159.2333     -5.80        66
#
#      Cloudiness  Wind Speed Current Description
# 0            15       13.96          few clouds
# 1            99        4.43     overcast clouds
# 2             0       20.71           clear sky
# 3            75        4.61       broken clouds
# 4             0       12.66           clear sky
# ..          ...         ...                 ...
# 680          98        5.59     overcast clouds
# 681         100       23.98     overcast clouds
# 682          99        7.38     overcast clouds
# 683          11        3.85          few clouds
# 684           4       14.16           clear sky
#
# [685 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_df.to_csv(output_data_file, index_label="City_ID")
