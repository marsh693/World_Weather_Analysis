# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size =2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size =2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 751

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | pevek
# Processing Record 3 of Set 1 | lompoc
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | aksum
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | north bend
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 1 | batagay
# Processing Record 11 of Set 1 | port hawkesbury
# Processing Record 12 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 1 | council bluffs
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | camden
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | richards bay
# Processing Record 22 of Set 1 | bonwapitse
# Processing Record 23 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | cap malheureux
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | kralendijk
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | lima
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | diveyevo
# Processing Record 38 of Set 1 | oussouye
# Processing Record 39 of Set 1 | talnakh
# Processing Record 40 of Set 1 | severo-kurilsk
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | hai phong
# City not found. Skipping...
# Processing Record 43 of Set 1 | haverfordwest
# Processing Record 44 of Set 1 | figeac
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | sokoni
# Processing Record 47 of Set 1 | katobu
# Processing Record 48 of Set 1 | grenfell
# Processing Record 49 of Set 1 | marsh harbour
# Processing Record 50 of Set 1 | bubaque
# Processing Record 1 of Set 2 | galdar
# Processing Record 2 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 2 | cabo san lucas
# Processing Record 4 of Set 2 | longyearbyen
# Processing Record 5 of Set 2 | santa rosa
# Processing Record 6 of Set 2 | laguna de perlas
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | zeya
# Processing Record 9 of Set 2 | faya
# Processing Record 10 of Set 2 | port hardy
# Processing Record 11 of Set 2 | obo
# Processing Record 12 of Set 2 | chaoyang
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | virginia beach
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 17 of Set 2 | cacu
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | prince rupert
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | hasaki
# Processing Record 22 of Set 2 | alofi
# Processing Record 23 of Set 2 | ushuaia
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | katsuura
# Processing Record 26 of Set 2 | cartagena del chaira
# Processing Record 27 of Set 2 | qasigiannguit
# Processing Record 28 of Set 2 | punta arenas
# Processing Record 29 of Set 2 | pozo colorado
# Processing Record 30 of Set 2 | san cristobal
# Processing Record 31 of Set 2 | anadyr
# Processing Record 32 of Set 2 | zalantun
# Processing Record 33 of Set 2 | aksu
# Processing Record 34 of Set 2 | muriwai beach
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | cape town
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | big rapids
# Processing Record 39 of Set 2 | roverud
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | nelson bay
# Processing Record 42 of Set 2 | psebay
# Processing Record 43 of Set 2 | mar del plata
# Processing Record 44 of Set 2 | kendari
# Processing Record 45 of Set 2 | tura
# Processing Record 46 of Set 2 | hongjiang
# Processing Record 47 of Set 2 | fairview
# Processing Record 48 of Set 2 | norman wells
# Processing Record 49 of Set 2 | touros
# Processing Record 50 of Set 2 | navahrudak
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | maxixe
# Processing Record 4 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 3 | airai
# Processing Record 6 of Set 3 | acari
# Processing Record 7 of Set 3 | kautokeino
# Processing Record 8 of Set 3 | butaritari
# Processing Record 9 of Set 3 | montrose
# Processing Record 10 of Set 3 | kaitangata
# Processing Record 11 of Set 3 | coffs harbour
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | namatanai
# Processing Record 14 of Set 3 | tigil
# Processing Record 15 of Set 3 | bang saphan
# Processing Record 16 of Set 3 | biak
# Processing Record 17 of Set 3 | hervey bay
# Processing Record 18 of Set 3 | provideniya
# Processing Record 19 of Set 3 | luderitz
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | carnarvon
# Processing Record 22 of Set 3 | gunnedah
# Processing Record 23 of Set 3 | mpraeso
# Processing Record 24 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 3 | smirnykh
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | cayenne
# Processing Record 28 of Set 3 | guerrero negro
# Processing Record 29 of Set 3 | buriti
# Processing Record 30 of Set 3 | progreso
# Processing Record 31 of Set 3 | coquimbo
# Processing Record 32 of Set 3 | mount isa
# Processing Record 33 of Set 3 | san policarpo
# Processing Record 34 of Set 3 | abalak
# Processing Record 35 of Set 3 | albertville
# Processing Record 36 of Set 3 | raychikhinsk
# Processing Record 37 of Set 3 | port lincoln
# Processing Record 38 of Set 3 | khatanga
# Processing Record 39 of Set 3 | kungurtug
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | fairbanks
# Processing Record 42 of Set 3 | georgetown
# Processing Record 43 of Set 3 | hohhot
# Processing Record 44 of Set 3 | grandview
# Processing Record 45 of Set 3 | hithadhoo
# Processing Record 46 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 47 of Set 3 | gat
# Processing Record 48 of Set 3 | kolhapur
# Processing Record 49 of Set 3 | narsaq
# Processing Record 50 of Set 3 | bengkulu
# Processing Record 1 of Set 4 | houlton
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | rosario
# Processing Record 4 of Set 4 | faanui
# Processing Record 5 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 4 | broken hill
# Processing Record 7 of Set 4 | chokurdakh
# Processing Record 8 of Set 4 | ponta do sol
# Processing Record 9 of Set 4 | pacific grove
# Processing Record 10 of Set 4 | cururupu
# Processing Record 11 of Set 4 | bambous virieux
# Processing Record 12 of Set 4 | bredasdorp
# Processing Record 13 of Set 4 | cervo
# Processing Record 14 of Set 4 | dossor
# Processing Record 15 of Set 4 | tasiilaq
# Processing Record 16 of Set 4 | saint anthony
# Processing Record 17 of Set 4 | moron
# Processing Record 18 of Set 4 | constitucion
# Processing Record 19 of Set 4 | kiruna
# Processing Record 20 of Set 4 | ixtapa
# Processing Record 21 of Set 4 | paez
# Processing Record 22 of Set 4 | usinsk
# Processing Record 23 of Set 4 | puerto ayora
# Processing Record 24 of Set 4 | romita
# Processing Record 25 of Set 4 | henties bay
# Processing Record 26 of Set 4 | tual
# Processing Record 27 of Set 4 | kropotkin
# Processing Record 28 of Set 4 | komsomolskiy
# Processing Record 29 of Set 4 | gushikawa
# Processing Record 30 of Set 4 | joao pinheiro
# Processing Record 31 of Set 4 | half moon bay
# Processing Record 32 of Set 4 | saint-philippe
# Processing Record 33 of Set 4 | necochea
# Processing Record 34 of Set 4 | sao jose da coroa grande
# Processing Record 35 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 36 of Set 4 | poum
# Processing Record 37 of Set 4 | penzance
# Processing Record 38 of Set 4 | lagoa
# Processing Record 39 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 4 | salalah
# Processing Record 41 of Set 4 | elko
# Processing Record 42 of Set 4 | vanimo
# Processing Record 43 of Set 4 | scarborough
# Processing Record 44 of Set 4 | clyde river
# Processing Record 45 of Set 4 | terra santa
# Processing Record 46 of Set 4 | bonthe
# Processing Record 47 of Set 4 | pilar
# Processing Record 48 of Set 4 | mezhova
# Processing Record 49 of Set 4 | lugovoy
# Processing Record 50 of Set 4 | brae
# Processing Record 1 of Set 5 | ulaangom
# Processing Record 2 of Set 5 | juan lacaze
# Processing Record 3 of Set 5 | alagoinhas
# Processing Record 4 of Set 5 | the valley
# Processing Record 5 of Set 5 | cockburn town
# Processing Record 6 of Set 5 | marang
# Processing Record 7 of Set 5 | leningradskiy
# Processing Record 8 of Set 5 | baykit
# Processing Record 9 of Set 5 | takoradi
# Processing Record 10 of Set 5 | hilo
# Processing Record 11 of Set 5 | pangnirtung
# Processing Record 12 of Set 5 | laguna
# Processing Record 13 of Set 5 | bardiyah
# Processing Record 14 of Set 5 | tuatapere
# Processing Record 15 of Set 5 | pucallpa
# Processing Record 16 of Set 5 | ostrovnoy
# Processing Record 17 of Set 5 | caldwell
# Processing Record 18 of Set 5 | deputatskiy
# Processing Record 19 of Set 5 | port blair
# Processing Record 20 of Set 5 | peruibe
# Processing Record 21 of Set 5 | mount gambier
# Processing Record 22 of Set 5 | vila velha
# Processing Record 23 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 5 | iberia
# Processing Record 25 of Set 5 | iquique
# Processing Record 26 of Set 5 | opobo
# City not found. Skipping...
# Processing Record 27 of Set 5 | pidhorodna
# Processing Record 28 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 5 | ancud
# Processing Record 30 of Set 5 | pisco
# Processing Record 31 of Set 5 | taoudenni
# Processing Record 32 of Set 5 | vostok
# Processing Record 33 of Set 5 | balykshi
# Processing Record 34 of Set 5 | ranong
# Processing Record 35 of Set 5 | misratah
# Processing Record 36 of Set 5 | tiksi
# Processing Record 37 of Set 5 | cabinda
# Processing Record 38 of Set 5 | sistranda
# Processing Record 39 of Set 5 | berlevag
# Processing Record 40 of Set 5 | grand gaube
# Processing Record 41 of Set 5 | rawson
# Processing Record 42 of Set 5 | nikolskoye
# Processing Record 43 of Set 5 | aswan
# Processing Record 44 of Set 5 | shchelyayur
# City not found. Skipping...
# Processing Record 45 of Set 5 | acapulco
# Processing Record 46 of Set 5 | xinpu
# Processing Record 47 of Set 5 | kamenka
# Processing Record 48 of Set 5 | wewak
# Processing Record 49 of Set 5 | taitung
# Processing Record 50 of Set 5 | esperance
# Processing Record 1 of Set 6 | northam
# Processing Record 2 of Set 6 | krasnogorskoye
# Processing Record 3 of Set 6 | yala
# Processing Record 4 of Set 6 | saint george
# Processing Record 5 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 6 | lephepe
# City not found. Skipping...
# Processing Record 7 of Set 6 | tiznit
# Processing Record 8 of Set 6 | mikuni
# Processing Record 9 of Set 6 | rolla
# Processing Record 10 of Set 6 | isangel
# Processing Record 11 of Set 6 | burica
# City not found. Skipping...
# Processing Record 12 of Set 6 | zhangye
# Processing Record 13 of Set 6 | mogadishu
# Processing Record 14 of Set 6 | seoni
# Processing Record 15 of Set 6 | emerald
# Processing Record 16 of Set 6 | burns lake
# Processing Record 17 of Set 6 | gambela
# Processing Record 18 of Set 6 | hanyang
# Processing Record 19 of Set 6 | lensk
# Processing Record 20 of Set 6 | evensk
# Processing Record 21 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 6 | bowen
# Processing Record 23 of Set 6 | tecoanapa
# Processing Record 24 of Set 6 | jalu
# Processing Record 25 of Set 6 | rosetta
# Processing Record 26 of Set 6 | luwuk
# Processing Record 27 of Set 6 | pitimbu
# Processing Record 28 of Set 6 | maputo
# Processing Record 29 of Set 6 | henderson
# Processing Record 30 of Set 6 | christchurch
# Processing Record 31 of Set 6 | leh
# Processing Record 32 of Set 6 | xingyi
# Processing Record 33 of Set 6 | mawlamyine
# Processing Record 34 of Set 6 | lewistown
# Processing Record 35 of Set 6 | puerto escondido
# Processing Record 36 of Set 6 | arona
# Processing Record 37 of Set 6 | luwingu
# Processing Record 38 of Set 6 | saint-augustin
# Processing Record 39 of Set 6 | nemuro
# Processing Record 40 of Set 6 | torbay
# Processing Record 41 of Set 6 | barcelos
# Processing Record 42 of Set 6 | shu
# Processing Record 43 of Set 6 | sedona
# Processing Record 44 of Set 6 | almaznyy
# Processing Record 45 of Set 6 | avera
# Processing Record 46 of Set 6 | sakakah
# Processing Record 47 of Set 6 | road town
# Processing Record 48 of Set 6 | lowestoft
# Processing Record 49 of Set 6 | sao joao da barra
# Processing Record 50 of Set 6 | angangxi
# City not found. Skipping...
# Processing Record 1 of Set 7 | puerto cabezas
# Processing Record 2 of Set 7 | yagodnoye
# Processing Record 3 of Set 7 | kodiak
# Processing Record 4 of Set 7 | alice springs
# Processing Record 5 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 7 | apricena
# Processing Record 7 of Set 7 | kavaratti
# Processing Record 8 of Set 7 | ugoofaaru
# Processing Record 9 of Set 7 | khandyga
# Processing Record 10 of Set 7 | klaksvik
# Processing Record 11 of Set 7 | neuquen
# Processing Record 12 of Set 7 | harper
# Processing Record 13 of Set 7 | cidreira
# Processing Record 14 of Set 7 | ahipara
# Processing Record 15 of Set 7 | le port
# Processing Record 16 of Set 7 | boo
# Processing Record 17 of Set 7 | santiago del estero
# Processing Record 18 of Set 7 | namibe
# Processing Record 19 of Set 7 | tromso
# Processing Record 20 of Set 7 | baruun-urt
# Processing Record 21 of Set 7 | yamada
# Processing Record 22 of Set 7 | alghero
# Processing Record 23 of Set 7 | nyurba
# Processing Record 24 of Set 7 | nauta
# Processing Record 25 of Set 7 | bireun
# Processing Record 26 of Set 7 | pangai
# Processing Record 27 of Set 7 | fernie
# Processing Record 28 of Set 7 | pabbi
# Processing Record 29 of Set 7 | buraydah
# Processing Record 30 of Set 7 | martapura
# Processing Record 31 of Set 7 | nanortalik
# Processing Record 32 of Set 7 | las navas
# Processing Record 33 of Set 7 | wawa
# Processing Record 34 of Set 7 | guapore
# Processing Record 35 of Set 7 | saint-pierre
# Processing Record 36 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 7 | svetlogorsk
# Processing Record 38 of Set 7 | chicama
# Processing Record 39 of Set 7 | dulce nombre de culmi
# Processing Record 40 of Set 7 | maneadero
# Processing Record 41 of Set 7 | la paz
# Processing Record 42 of Set 7 | sydney
# Processing Record 43 of Set 7 | wencheng
# Processing Record 44 of Set 7 | houma
# Processing Record 45 of Set 7 | kikwit
# Processing Record 46 of Set 7 | poli
# Processing Record 47 of Set 7 | atar
# Processing Record 48 of Set 7 | simbahan
# Processing Record 49 of Set 7 | ilukste
# Processing Record 50 of Set 7 | wad madani
# Processing Record 1 of Set 8 | kurumkan
# Processing Record 2 of Set 8 | zhuhai
# Processing Record 3 of Set 8 | ilulissat
# Processing Record 4 of Set 8 | santa isabel do rio negro
# Processing Record 5 of Set 8 | fort-shevchenko
# Processing Record 6 of Set 8 | erenhot
# Processing Record 7 of Set 8 | emet
# Processing Record 8 of Set 8 | chara
# Processing Record 9 of Set 8 | amguri
# Processing Record 10 of Set 8 | korla
# Processing Record 11 of Set 8 | san alejo
# Processing Record 12 of Set 8 | gladstone
# Processing Record 13 of Set 8 | manokwari
# Processing Record 14 of Set 8 | honningsvag
# Processing Record 15 of Set 8 | tselinnoye
# Processing Record 16 of Set 8 | bayan
# Processing Record 17 of Set 8 | kitakami
# Processing Record 18 of Set 8 | nishihara
# Processing Record 19 of Set 8 | flin flon
# Processing Record 20 of Set 8 | trzebiatow
# Processing Record 21 of Set 8 | castro verde
# Processing Record 22 of Set 8 | devonport
# Processing Record 23 of Set 8 | mahajanga
# Processing Record 24 of Set 8 | rocha
# Processing Record 25 of Set 8 | walvis bay
# Processing Record 26 of Set 8 | iralaya
# Processing Record 27 of Set 8 | caravelas
# Processing Record 28 of Set 8 | cochabamba
# Processing Record 29 of Set 8 | uroteppa
# City not found. Skipping...
# Processing Record 30 of Set 8 | mozarlandia
# Processing Record 31 of Set 8 | chuy
# Processing Record 32 of Set 8 | oktyabrskoye
# Processing Record 33 of Set 8 | sao miguel do araguaia
# Processing Record 34 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 35 of Set 8 | ayan
# Processing Record 36 of Set 8 | kavieng
# Processing Record 37 of Set 8 | lavrentiya
# Processing Record 38 of Set 8 | victoria
# Processing Record 39 of Set 8 | todos santos
# Processing Record 40 of Set 8 | muzhi
# Processing Record 41 of Set 8 | aklavik
# Processing Record 42 of Set 8 | pizhanka
# Processing Record 43 of Set 8 | bernardino de campos
# Processing Record 44 of Set 8 | gornyy
# Processing Record 45 of Set 8 | bulawayo
# Processing Record 46 of Set 8 | mahanoro
# Processing Record 47 of Set 8 | camacha
# Processing Record 48 of Set 8 | kilindoni
# Processing Record 49 of Set 8 | acarau
# Processing Record 50 of Set 8 | isiro
# Processing Record 1 of Set 9 | maniitsoq
# Processing Record 2 of Set 9 | meulaboh
# Processing Record 3 of Set 9 | kattivakkam
# Processing Record 4 of Set 9 | yulara
# Processing Record 5 of Set 9 | luanda
# Processing Record 6 of Set 9 | plouzane
# Processing Record 7 of Set 9 | husavik
# Processing Record 8 of Set 9 | urumqi
# Processing Record 9 of Set 9 | maryborough
# Processing Record 10 of Set 9 | sao felix do xingu
# Processing Record 11 of Set 9 | mzimba
# Processing Record 12 of Set 9 | hammerfest
# Processing Record 13 of Set 9 | ajdabiya
# Processing Record 14 of Set 9 | turukhansk
# Processing Record 15 of Set 9 | bonavista
# Processing Record 16 of Set 9 | apple valley
# Processing Record 17 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 9 | port-gentil
# Processing Record 19 of Set 9 | petrokamenskoye
# Processing Record 20 of Set 9 | lazaro cardenas
# Processing Record 21 of Set 9 | pemangkat
# Processing Record 22 of Set 9 | concarneau
# Processing Record 23 of Set 9 | jiuquan
# Processing Record 24 of Set 9 | coihaique
# Processing Record 25 of Set 9 | rio gallegos
# Processing Record 26 of Set 9 | san antonio
# Processing Record 27 of Set 9 | camopi
# Processing Record 28 of Set 9 | tshikapa
# Processing Record 29 of Set 9 | herat
# Processing Record 30 of Set 9 | qaqortoq
# Processing Record 31 of Set 9 | saldanha
# Processing Record 32 of Set 9 | roald
# Processing Record 33 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 34 of Set 9 | sitka
# Processing Record 35 of Set 9 | shubarkuduk
# Processing Record 36 of Set 9 | wanaka
# Processing Record 37 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 9 | margate
# Processing Record 39 of Set 9 | sao filipe
# Processing Record 40 of Set 9 | pitkyaranta
# Processing Record 41 of Set 9 | podor
# Processing Record 42 of Set 9 | veraval
# Processing Record 43 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 44 of Set 9 | prudnik
# Processing Record 45 of Set 9 | codrington
# Processing Record 46 of Set 9 | price
# Processing Record 47 of Set 9 | bengkalis
# City not found. Skipping...
# Processing Record 48 of Set 9 | iseyin
# Processing Record 49 of Set 9 | adrar
# Processing Record 50 of Set 9 | nadym
# Processing Record 1 of Set 10 | imeni poliny osipenko
# Processing Record 2 of Set 10 | mehamn
# Processing Record 3 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 4 of Set 10 | preston
# Processing Record 5 of Set 10 | srednekolymsk
# Processing Record 6 of Set 10 | sayyan
# Processing Record 7 of Set 10 | nanga eboko
# Processing Record 8 of Set 10 | brokopondo
# Processing Record 9 of Set 10 | tera
# Processing Record 10 of Set 10 | navabad
# City not found. Skipping...
# Processing Record 11 of Set 10 | biltine
# Processing Record 12 of Set 10 | filingue
# Processing Record 13 of Set 10 | bilma
# Processing Record 14 of Set 10 | auki
# Processing Record 15 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 16 of Set 10 | oranjemund
# Processing Record 17 of Set 10 | poya
# Processing Record 18 of Set 10 | taian
# Processing Record 19 of Set 10 | cap-aux-meules
# Processing Record 20 of Set 10 | kutum
# Processing Record 21 of Set 10 | bose
# Processing Record 22 of Set 10 | pouembout
# Processing Record 23 of Set 10 | beringovskiy
# Processing Record 24 of Set 10 | saint-andre-les-vergers
# Processing Record 25 of Set 10 | morondava
# Processing Record 26 of Set 10 | kailua
# Processing Record 27 of Set 10 | mandera
# Processing Record 28 of Set 10 | banda aceh
# Processing Record 29 of Set 10 | port macquarie
# Processing Record 30 of Set 10 | tucumcari
# Processing Record 31 of Set 10 | vila franca do campo
# Processing Record 32 of Set 10 | shaunavon
# Processing Record 33 of Set 10 | kindu
# Processing Record 34 of Set 10 | baduria
# Processing Record 35 of Set 10 | tabuk
# Processing Record 36 of Set 10 | jinchang
# Processing Record 37 of Set 10 | salinopolis
# Processing Record 38 of Set 10 | kassala
# Processing Record 39 of Set 10 | hovd
# Processing Record 40 of Set 10 | cherskiy
# Processing Record 41 of Set 10 | uige
# Processing Record 42 of Set 10 | sola
# Processing Record 43 of Set 10 | baft
# Processing Record 44 of Set 10 | umea
# Processing Record 45 of Set 10 | preobrazheniye
# Processing Record 46 of Set 10 | naze
# Processing Record 47 of Set 10 | yar-sale
# Processing Record 48 of Set 10 | hamilton
# Processing Record 49 of Set 10 | waddan
# Processing Record 50 of Set 10 | ialibu
# Processing Record 1 of Set 11 | warrnambool
# Processing Record 2 of Set 11 | okha
# Processing Record 3 of Set 11 | hobyo
# Processing Record 4 of Set 11 | zyryanka
# Processing Record 5 of Set 11 | nome
# Processing Record 6 of Set 11 | doha
# Processing Record 7 of Set 11 | grindavik
# Processing Record 8 of Set 11 | launceston
# Processing Record 9 of Set 11 | geilo
# Processing Record 10 of Set 11 | chapais
# Processing Record 11 of Set 11 | pakwach
# City not found. Skipping...
# Processing Record 12 of Set 11 | asau
# Processing Record 13 of Set 11 | camargo
# Processing Record 14 of Set 11 | glasgow
# Processing Record 15 of Set 11 | urengoy
# Processing Record 16 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 11 | jiangyou
# Processing Record 18 of Set 11 | dhidhdhoo
# Processing Record 19 of Set 11 | dukat
# Processing Record 20 of Set 11 | ampanihy
# Processing Record 21 of Set 11 | perg
# Processing Record 22 of Set 11 | sobolevo
# Processing Record 23 of Set 11 | ouadda
# Processing Record 24 of Set 11 | axim
# Processing Record 25 of Set 11 | moji das cruzes
# City not found. Skipping...
# Processing Record 26 of Set 11 | pareora
# Processing Record 27 of Set 11 | egvekinot
# Processing Record 28 of Set 11 | kruisfontein
# Processing Record 29 of Set 11 | mollendo
# Processing Record 30 of Set 11 | buchanan
# Processing Record 31 of Set 11 | bereda
# Processing Record 32 of Set 11 | vidim
# Processing Record 33 of Set 11 | zhengjiatun
# Processing Record 34 of Set 11 | san jose de ocoa
# Processing Record 35 of Set 11 | santa cruz de la palma
# Processing Record 36 of Set 11 | inuvik
# Processing Record 37 of Set 11 | camana
# Processing Record 38 of Set 11 | wellington
# Processing Record 39 of Set 11 | inverell
# Processing Record 40 of Set 11 | tingi
# Processing Record 41 of Set 11 | sulangan
# Processing Record 42 of Set 11 | college
# Processing Record 43 of Set 11 | san patricio
# Processing Record 44 of Set 11 | tombouctou
# Processing Record 45 of Set 11 | dickinson
# Processing Record 46 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 11 | trincomalee
# Processing Record 48 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 11 | djibo
# Processing Record 50 of Set 11 | carpinteria
# Processing Record 1 of Set 12 | bambanglipuro
# Processing Record 2 of Set 12 | cuiluan
# Processing Record 3 of Set 12 | samarai
# Processing Record 4 of Set 12 | westport
# Processing Record 5 of Set 12 | dwarka
# Processing Record 6 of Set 12 | mongoumba
# Processing Record 7 of Set 12 | bosaso
# Processing Record 8 of Set 12 | pombia
# Processing Record 9 of Set 12 | watsa
# Processing Record 10 of Set 12 | visby
# Processing Record 11 of Set 12 | nuuk
# Processing Record 12 of Set 12 | we
# City not found. Skipping...
# Processing Record 13 of Set 12 | aktash
# Processing Record 14 of Set 12 | higuey
# City not found. Skipping...
# Processing Record 15 of Set 12 | sechura
# Processing Record 16 of Set 12 | sur
# Processing Record 17 of Set 12 | lorengau
# Processing Record 18 of Set 12 | mackay
# Processing Record 19 of Set 12 | awjilah
# Processing Record 20 of Set 12 | tarnogskiy gorodok
# Processing Record 21 of Set 12 | manbij
# Processing Record 22 of Set 12 | diffa
# Processing Record 23 of Set 12 | soyo
# Processing Record 24 of Set 12 | santa fe
# Processing Record 25 of Set 12 | kampene
# Processing Record 26 of Set 12 | freeport
# Processing Record 27 of Set 12 | maceio
# Processing Record 28 of Set 12 | coahuayana
# Processing Record 29 of Set 12 | hami
# Processing Record 30 of Set 12 | mombetsu
# Processing Record 31 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 32 of Set 12 | jorhat
# Processing Record 33 of Set 12 | haian
# Processing Record 34 of Set 12 | winona
# Processing Record 35 of Set 12 | mareeba
# Processing Record 36 of Set 12 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 37 of Set 12 | padang
# Processing Record 38 of Set 12 | bonnyville
# Processing Record 39 of Set 12 | maragogi
# Processing Record 40 of Set 12 | kankan
# Processing Record 41 of Set 12 | maridi
# Processing Record 42 of Set 12 | maloy
# Processing Record 43 of Set 12 | kahului
# Processing Record 44 of Set 12 | homa bay
# Processing Record 45 of Set 12 | lucea
# Processing Record 46 of Set 12 | juegang
# Processing Record 47 of Set 12 | portland
# Processing Record 48 of Set 12 | letterkenny
# Processing Record 49 of Set 12 | tayu
# Processing Record 50 of Set 12 | blythe
# Processing Record 1 of Set 13 | gardan diwal
# City not found. Skipping...
# Processing Record 2 of Set 13 | dongfeng
# Processing Record 3 of Set 13 | taveta
# Processing Record 4 of Set 13 | belen
# Processing Record 5 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 13 | ieud
# Processing Record 7 of Set 13 | sambava
# Processing Record 8 of Set 13 | tagusao
# Processing Record 9 of Set 13 | labuhan
# Processing Record 10 of Set 13 | banyo
# Processing Record 11 of Set 13 | nanchong
# Processing Record 12 of Set 13 | sivaki
# Processing Record 13 of Set 13 | dudinka
# Processing Record 14 of Set 13 | aki
# Processing Record 15 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 16 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 13 | vzmorye
# Processing Record 18 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 13 | lodja
# Processing Record 20 of Set 13 | jinchengjiang
# City not found. Skipping...
# Processing Record 21 of Set 13 | flinders
# Processing Record 22 of Set 13 | trelleborg
# Processing Record 23 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 24 of Set 13 | kentville
# Processing Record 25 of Set 13 | xining
# Processing Record 26 of Set 13 | ligayan
# Processing Record 27 of Set 13 | bay roberts
# Processing Record 28 of Set 13 | vradiyivka
# Processing Record 29 of Set 13 | havoysund
# Processing Record 30 of Set 13 | chingirlau
# Processing Record 31 of Set 13 | guicheng
# City not found. Skipping...
# Processing Record 32 of Set 13 | ngunguru
# Processing Record 33 of Set 13 | lixourion
# Processing Record 34 of Set 13 | huarmey
# Processing Record 35 of Set 13 | iqaluit
# Processing Record 36 of Set 13 | pangody
# Processing Record 37 of Set 13 | ewa beach
# Processing Record 38 of Set 13 | port hedland
# Processing Record 39 of Set 13 | mounana
# Processing Record 40 of Set 13 | umtata
# Processing Record 41 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 42 of Set 13 | beisfjord
# Processing Record 43 of Set 13 | hue
# Processing Record 44 of Set 13 | mallama
# City not found. Skipping...
# Processing Record 45 of Set 13 | luganville
# Processing Record 46 of Set 13 | son la
# Processing Record 47 of Set 13 | toulepleu
# City not found. Skipping...
# Processing Record 48 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 13 | matara
# Processing Record 50 of Set 13 | vardo
# Processing Record 1 of Set 14 | mao
# Processing Record 2 of Set 14 | hokitika
# Processing Record 3 of Set 14 | sinjar
# Processing Record 4 of Set 14 | bossangoa
# Processing Record 5 of Set 14 | yuanping
# Processing Record 6 of Set 14 | ambilobe
# Processing Record 7 of Set 14 | heias
# City not found. Skipping...
# Processing Record 8 of Set 14 | deder
# Processing Record 9 of Set 14 | kuminskiy
# Processing Record 10 of Set 14 | atherton
# Processing Record 11 of Set 14 | broome
# Processing Record 12 of Set 14 | vaitape
# Processing Record 13 of Set 14 | muros
# Processing Record 14 of Set 14 | afonso bezerra
# Processing Record 15 of Set 14 | rosarito
# Processing Record 16 of Set 14 | toribio
# Processing Record 17 of Set 14 | las lomas
# Processing Record 18 of Set 14 | padron
# Processing Record 19 of Set 14 | karratha
# Processing Record 20 of Set 14 | draguignan
# Processing Record 21 of Set 14 | dayong
# Processing Record 22 of Set 14 | lamu
# Processing Record 23 of Set 14 | aksarayskiy
# Processing Record 24 of Set 14 | tahe
# Processing Record 25 of Set 14 | manzini
# Processing Record 26 of Set 14 | skovde
# City not found. Skipping...
# Processing Record 27 of Set 14 | comodoro rivadavia
# Processing Record 28 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 29 of Set 14 | thunder bay
# Processing Record 30 of Set 14 | bukama
# Processing Record 31 of Set 14 | garowe
# Processing Record 32 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 14 | porto novo
# Processing Record 34 of Set 14 | cape elizabeth
# City not found. Skipping...
# Processing Record 35 of Set 14 | carmen
# Processing Record 36 of Set 14 | paita
# Processing Record 37 of Set 14 | tocopilla
# Processing Record 38 of Set 14 | buluang
# Processing Record 39 of Set 14 | sioux lookout
# Processing Record 40 of Set 14 | wakkanai
# Processing Record 41 of Set 14 | guelengdeng
# City not found. Skipping...
# Processing Record 42 of Set 14 | teguldet
# Processing Record 43 of Set 14 | haines junction
# Processing Record 44 of Set 14 | kuhestan
# City not found. Skipping...
# Processing Record 45 of Set 14 | santana
# Processing Record 46 of Set 14 | dergachi
# Processing Record 47 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 14 | teknaf
# Processing Record 49 of Set 14 | union
# Processing Record 50 of Set 14 | navapur
# City not found. Skipping...
# Processing Record 1 of Set 15 | araouane
# Processing Record 2 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 15 | shenzhen
# Processing Record 4 of Set 15 | bima
# Processing Record 5 of Set 15 | kysyl-syr
# Processing Record 6 of Set 15 | el ejido
# Processing Record 7 of Set 15 | daru
# Processing Record 8 of Set 15 | ukiah
# Processing Record 9 of Set 15 | honiara
# Processing Record 10 of Set 15 | bilibino
# Processing Record 11 of Set 15 | tunceli
# Processing Record 12 of Set 15 | suez
# Processing Record 13 of Set 15 | fereydun kenar
# Processing Record 14 of Set 15 | whitley bay
# Processing Record 15 of Set 15 | hofn
# Processing Record 16 of Set 15 | nouadhibou
# Processing Record 17 of Set 15 | pennsville
# Processing Record 18 of Set 15 | usogorsk
# Processing Record 19 of Set 15 | champasak
# Processing Record 20 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 21 of Set 15 | taltal
# Processing Record 22 of Set 15 | caledon
# Processing Record 23 of Set 15 | pierre
# Processing Record 24 of Set 15 | ust-nera
# Processing Record 25 of Set 15 | fort smith
# Processing Record 26 of Set 15 | batangafo
# Processing Record 27 of Set 15 | phenix city
# Processing Record 28 of Set 15 | batemans bay
# Processing Record 29 of Set 15 | mushie
# Processing Record 30 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 15 | lakes entrance
# Processing Record 32 of Set 15 | oga
# Processing Record 33 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 15 | goderich
# Processing Record 35 of Set 15 | ofunato
# Processing Record 36 of Set 15 | lexington
# Processing Record 37 of Set 15 | saquena
# Processing Record 38 of Set 15 | salym
# Processing Record 39 of Set 15 | tessalit
# Processing Record 40 of Set 15 | meadow lake
# Processing Record 41 of Set 15 | igarka
# Processing Record 42 of Set 15 | bolshaya izhora
# Processing Record 43 of Set 15 | gazli
# Processing Record 44 of Set 15 | pindushi
# Processing Record 45 of Set 15 | shitanjing
# Processing Record 46 of Set 15 | eydhafushi
# Processing Record 47 of Set 15 | okhotsk
# Processing Record 48 of Set 15 | roma
# Processing Record 49 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 1 of Set 16 | kampong thum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 677

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Pevek  69.7008  170.3133    -27.89       100          20
# 1           Lompoc  34.6391 -120.4579     56.52        87         100
# 2         Thompson  55.7435  -97.8558      5.16        85         100
# 3            Aksum  14.1245   38.7244     58.53        67          40
# 4           Bethel  41.3712  -73.4140     39.06        52           0
# 5       North Bend  43.4065 -124.2243     49.91        93         100
# 6            Bluff -46.6000  168.3333     64.83        67           1
# 7          Batagay  67.6333  134.6333    -49.67       100          97
# 8  Port Hawkesbury  45.6169  -61.3485     36.99        98         100
# 9   Council Bluffs  41.2619  -95.8608     47.41        68         100
#
#    Wind Speed Country Current Description
# 0        2.62      RU          few clouds
# 1        8.05      US                mist
# 2        5.75      CA          light snow
# 3        1.99      ET    scattered clouds
# 4        9.22      US           clear sky
# 5        8.05      US     overcast clouds
# 6        2.48      NZ           clear sky
# 7        0.94      RU     overcast clouds
# 8       17.00      CA       moderate rain
# 9       13.80      US     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity',
                    'Cloudiness', 'Wind Speed', 'Current Description'] 

# Recreate the DataFrame by using the new column order
city_df = city_data_df[new_column_order]
city_df.head(10)

# Display sample data
city_df
# Out:
#                           City Country      Lat       Lng  Max Temp  Humidity  \
# 0                        Pevek      RU  69.7008  170.3133    -27.89       100
# 1                       Lompoc      US  34.6391 -120.4579     56.52        87
# 2                     Thompson      CA  55.7435  -97.8558      5.16        85
# 3                        Aksum      ET  14.1245   38.7244     58.53        67
# 4                       Bethel      US  41.3712  -73.4140     39.06        52
# ..                         ...     ...      ...       ...       ...       ...
# 672                 Eydhafushi      MV   5.1033   73.0708     79.70        74
# 673                    Okhotsk      RU  59.3833  143.3000    -10.73        90
# 674                       Roma      US  43.2128  -75.4557     21.81        87
# 675  Petropavlovsk-Kamchatskiy      RU  53.0452  158.6483      7.39        43
# 676               Kampong Thum      KH  12.7111  104.8887     68.58        88
#
#      Cloudiness  Wind Speed Current Description
# 0            20        2.62          few clouds
# 1           100        8.05                mist
# 2           100        5.75          light snow
# 3            40        1.99    scattered clouds
# 4             0        9.22           clear sky
# ..          ...         ...                 ...
# 672          63        8.63       broken clouds
# 673         100       17.54     overcast clouds
# 674          75        6.91       broken clouds
# 675          30       17.90    scattered clouds
# 676           7        5.17           clear sky
#
# [677 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_df.to_csv(output_data_file, index_label="City_ID")
